# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
planets=sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# ### 1. Use Pandas to display a summary of the dataset, including count, mean, min, and max for the numerical columns.

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# ### 2.For the method column, calculate the count of planets discovered using each method. Which method is the most common?

# %%
planets['method'].value_counts()
# Out:
# method
# radial velocity                  553
# transit                          397
# imaging                           38
# microlensing                      23
# eclipse timing variations          9
# pulsar timing                      5
# transit timing variations          4
# orbital brightness modulation      3
# astrometry                         2
# pulsation timing variations        1
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Create a new DataFrame that contains only planets with an orbital_period greater than 200 days. How many planets meet this criteria?

# %%
orbitperiod=planets[planets['orbital_period']>200]['orbital_period']

# %%
orbit=pd.DataFrame(orbitperiod)
orbit
# Out:
#      orbital_period
# 0           269.300
# 1           874.774
# 2           763.000
# 3           326.030
# 4           516.220
# ..              ...
# 921        1825.000
# 922        5100.000
# 937      730000.000
# 944       36525.000
# 958        1170.000
#
# [368 rows x 1 columns]

# %% [markdown]
# ### 4. Sort the DataFrame by mass in descending order. What are the top three most massive planets in your dataset?

# %%
planets.sort_values("mass",ascending=False)
# Out:
#                method  number  orbital_period   mass  distance  year
# 321   Radial Velocity       1     2371.000000  25.00     37.05  2008
# 85    Radial Velocity       2      379.630000  21.42       NaN  2009
# 63    Radial Velocity       1      305.500000  20.60     92.51  2013
# 913   Radial Velocity       1      677.800000  19.80       NaN  2007
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.sort_values("mass",ascending=False).head(3)
# Out:
#               method  number  orbital_period   mass  distance  year
# 321  Radial Velocity       1         2371.00  25.00     37.05  2008
# 85   Radial Velocity       2          379.63  21.42       NaN  2009
# 63   Radial Velocity       1          305.50  20.60     92.51  2013

# %% [markdown]
# ### 5. Group the data by year and count the number of planets discovered each year. What year had the highest number of discoveries?

# %%
count_of_planets=planets.groupby("year")['number'].count()
count_of_planets
# Out:
# year
# 1989      1
# 1992      2
# 1994      1
# 1995      1
# 1996      6
# 1997      1
# 1998      5
# 1999     15
# 2000     16
# 2001     12
# 2002     32
# 2003     25
# 2004     26
# 2005     39
# 2006     31
# 2007     53
# 2008     74
# 2009     98
# 2010    102
# 2011    185
# 2012    140
# 2013    118
# 2014     52
# Name: number, dtype: int64

# %% [markdown]
# ### 6. Check for any missing values in the dataset. How many missing values are in each column.

# %%
planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %% [markdown]
# ### 7. Create a subset of the dataset containing only the columns mass, orbital_period, and year.

# %%
planets[["mass","orbital_period","year"]]
# Out:
#        mass  orbital_period  year
# 0      7.10      269.300000  2006
# 1      2.21      874.774000  2008
# 2      2.60      763.000000  2011
# 3     19.40      326.030000  2007
# 4     10.50      516.220000  2009
# ...     ...             ...   ...
# 1030    NaN        3.941507  2006
# 1031    NaN        2.615864  2007
# 1032    NaN        3.191524  2007
# 1033    NaN        4.125083  2008
# 1034    NaN        4.187757  2008
#
# [1035 rows x 3 columns]

# %% [markdown]
# ### 8. Using NumPy, calculate the mean and standard deviation of the mass of the planets.

# %%
np.mean(planets["mass"])
# Out:
# 2.6381605847953216

# %%
np.std(planets["mass"])
# Out:
# 3.814892986837594

# %% [markdown]
# ### 9.Convert the orbital_period column to a NumPy array and calculate the median orbital period.

# %%
a=planets["orbital_period"].to_numpy()
np.median(a)
# Out:
# nan

# %% [markdown]
# ### 10. Use NumPy to filter the distance array to find planets that are more than 100 light-years away. How many planets fit this criterion?

# %%
a=planets['distance'].to_numpy()
b=a[a>100]
b
# Out:
# array([ 110.62,  119.47,  165.  ,  140.  ,  145.  ,  139.  ,  130.72,
#         130.72,  500.  ,  500.  ,  145.  ,  140.  ,  175.44,  200.  ,
#         680.  ,  150.  ,  150.  ,  380.  ,  460.  ,  345.  ,  560.  ,
#        1150.  , 1060.  , 1340.  ,  840.  ,  920.  ,  870.  ,  770.  ,
#        1230.  ,  600.  ,  145.  ,  139.  ,  135.32,  138.  ,  314.  ,
#         342.  ,  261.  ,  230.  ,  480.  ,  142.5 ,  214.  ,  214.  ,
#         205.  ,  190.  ,  235.  ,  166.  ,  215.  ,  254.  ,  393.  ,
#         396.  ,  297.  ,  134.  ,  204.  ,  395.  ,  322.  ,  193.  ,
#         354.  ,  354.  ,  283.  ,  387.  ,  257.  ,  535.  ,  317.  ,
#         411.  ,  249.  ,  642.  ,  501.  ,  344.  ,  447.  ,  542.  ,
#         322.  ,  303.  ,  360.  ,  453.  ,  167.5 ,  115.21,  131.41,
#         150.6 ,  300.3 ,  127.88,  168.92,  121.07,  136.8 ,  117.37,
#         121.36,  121.36,  112.23,  149.03,  132.8 ,  221.24,  150.38,
# ...

# %% [markdown]
# ### 11. Use NumPy to calculate the correlation coefficient between mass and orbital_period. What does this value indicate about their relationship?

# %%
planets1=planets.dropna(subset=['mass','orbital_period'])

# %%
mass=np.array(planets1['mass'])
orbital=np.array(planets1['orbital_period'])

# %%
np.corrcoef(x=mass,y=orbital)
# Out:
# array([[1.        , 0.17372547],
#        [0.17372547, 1.        ]])

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ### 12, Create a bar plot showing the count of planets discovered by each method. How does the number of discoveries vary by method

# %%
x=planets['method'].value_counts()
plt.bar(x.index,x.values,color='red')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### 13. Create a histogram of the mass of the planets.

# %%
plt.hist(planets['mass'],color='#FFC0CB')
# Out:
# (array([358.,  70.,  34.,  21.,  12.,   7.,   3.,   5.,   2.,   1.]),
#  array([3.600000e-03, 2.503240e+00, 5.002880e+00, 7.502520e+00,
#         1.000216e+01, 1.250180e+01, 1.500144e+01, 1.750108e+01,
#         2.000072e+01, 2.250036e+01, 2.500000e+01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 14.Plot the number of discoveries over the years using a line plot.

# %%
x=planets['year'].value_counts()
plt.plot(x.index,x.values,'y--.')

# %% [markdown]
# ### 15.Create a scatter plot to visualize the relationship between mass and orbital_period.

# %%
plt.scatter(planets['mass'],planets['orbital_period'],color='#800080')

# %% [markdown]
# ### 16. Create a box plot of mass for different methods of discovery.

# %%
sns.boxplot(data=planets, x='method', y='mass')
# Out:
# <Axes: xlabel='method', ylabel='mass'>

# %% [markdown]
# ### 17. Use Seaborn to create a count plot of the method column. Which method has the most discoveries, and how does this relate to the other methods?

# %%
sns.countplot(x='method',data=planets)
# Out:
# <Axes: xlabel='method', ylabel='count'>

# %% [markdown]
# ### 18. Create a pair plot for the columns mass, orbital_period, and distance. What relationships do you notice among these variables?

# %%
sns.pairplot(planets)
# Out:
# C:\Users\edure\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 19.Use a violin plot to show the distribution of mass for different methods.

# %%
sns.violinplot(x="mass",y="method",data=planets)
# Out:
# <Axes: xlabel='mass', ylabel='method'>

# %% [markdown]
# ### 20. Generate a heatmap to visualize the correlation matrix of the numerical columns in the dataset. Which variables are most strongly correlated?

# %%
planets.corr(numeric_only=True)
sns.heatmap(planets.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
